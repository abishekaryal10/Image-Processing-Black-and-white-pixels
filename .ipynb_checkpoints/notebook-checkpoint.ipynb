# %%
# %matplotlib inline
import matplotlib.pyplot as plt
from skimage.filters.rank import entropy
from skimage.morphology import disk
from skimage import transform
from skimage import io, img_as_float
import numpy as np
import glob
from scipy import ndimage
import os
from loguru import logger
import pandas as pd

# %%
from skimage.filters import try_all_threshold, threshold_otsu, threshold_yen, gaussian

# %% [markdown]
# # Testing

# %%
# pip install scikit-image

# %%
pwd = "./Before and after pictures/M23"
# pwd = "./Before and after pictures/M19"
img_paths = os.listdir(pwd)
img_paths
# Out:
# ['After M23.jpg', 'Before M23.jpg']

# %%
b_img = io.imread(f"{pwd}/{img_paths[1]}", as_gray=True)
plt.imshow(b_img, cmap="gray")

# %%
def get_pixel_count(og_img: np.ndarray, debug=False, fname="", new_size=(1000, 1000)):
    resized_img = transform.resize(og_img, new_size, anti_aliasing=True)
    img = gaussian(resized_img, sigma=3.0)
    threshold = threshold_yen(img)
    logger.info(f"Best threshold {threshold}")
    binary_img = img >= threshold
    logger.info(f"Original Image {og_img.shape} -> {binary_img.shape}")
    
    if fname:
        logger.info(fname)
        io.imsave(f"binary_output/bin_{fname}", binary_img)
        io.imsave(f"resized_images/R_{fname}", (resized_img * 255).astype(np.uint8))
    if debug:
        logger.info("Debugging enabled.")
        logger.info(f"white pixel -> {np.sum(binary_img==1)} | black pixel {np.sum(binary_img==0)}.")
        fig, axes = plt.subplots(nrows=1, ncols=3)
        
        ax = axes.ravel()
        ax[0].imshow(og_img, cmap='gray')
        ax[0].set_title("Original image")
        
        ax[1].imshow(resized_img, cmap='gray')
        ax[1].set_title("Resized image (aliasing)")
        
        ax[2].imshow(binary_img, cmap='gray')
        ax[2].set_title("Binary (no aliasing)")
        
        plt.tight_layout()
        plt.show()
    
    black_pixel = np.sum(binary_img==0)
    white_pixel = np.sum(binary_img==1)
    total = black_pixel + white_pixel
    return black_pixel, white_pixel, (black_pixel/total) * 100

# %%
logger.info(img_paths[1])
img_1 = io.imread(f"{pwd}/{img_paths[1]}", as_gray=True)

# entr_img = entropy(a_img, disk(1))
logger.info(img_1.shape)
get_pixel_count(img_1, debug=True, fname=img_paths[1])
# Out:
# 2023-08-03 07:01:08.592 | INFO     | __main__:<module>:1 - Before M23.jpg
# 2023-08-03 07:01:08.608 | INFO     | __main__:<module>:5 - (932, 982)
# 2023-08-03 07:01:08.669 | INFO     | __main__:get_pixel_count:5 - Best threshold 0.5498565934668658
# 2023-08-03 07:01:08.670 | INFO     | __main__:get_pixel_count:7 - Original Image (932, 982) -> (1000, 1000)
# 2023-08-03 07:01:08.670 | INFO     | __main__:get_pixel_count:10 - Before M23.jpg
# /tmp/ipykernel_7958/217959107.py:11: UserWarning: binary_output/bin_Before M23.jpg is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
#   io.imsave(f"binary_output/bin_{fname}", binary_img)
# /tmp/ipykernel_7958/217959107.py:11: UserWarning: binary_output/bin_Before M23.jpg is a low contrast image
#   io.imsave(f"binary_output/bin_{fname}", binary_img)
# 2023-08-03 07:01:08.688 | INFO     | __main__:get_pixel_count:14 - Debugging enabled.
# 2023-08-03 07:01:08.692 | INFO     | __main__:get_pixel_count:15 - white pixel -> 997011 | black pixel 2989.
# (2989, 997011, 0.2989)

# %%
logger.info(img_paths[0])
img_2 = io.imread(f"{pwd}/{img_paths[0]}", as_gray=True)
# entr_img = entropy(a_img, disk(1))
get_pixel_count(img_2, debug=True, fname=img_paths[0])
# Out:
# 2023-08-03 07:01:12.008 | INFO     | __main__:<module>:1 - After M23.jpg
# 2023-08-03 07:01:12.090 | INFO     | __main__:get_pixel_count:5 - Best threshold 0.5111901110340389
# 2023-08-03 07:01:12.091 | INFO     | __main__:get_pixel_count:7 - Original Image (994, 1011) -> (1000, 1000)
# 2023-08-03 07:01:12.092 | INFO     | __main__:get_pixel_count:10 - After M23.jpg
# /tmp/ipykernel_7958/217959107.py:11: UserWarning: binary_output/bin_After M23.jpg is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
#   io.imsave(f"binary_output/bin_{fname}", binary_img)
# /tmp/ipykernel_7958/217959107.py:11: UserWarning: binary_output/bin_After M23.jpg is a low contrast image
#   io.imsave(f"binary_output/bin_{fname}", binary_img)
# 2023-08-03 07:01:12.109 | INFO     | __main__:get_pixel_count:14 - Debugging enabled.
# 2023-08-03 07:01:12.113 | INFO     | __main__:get_pixel_count:15 - white pixel -> 998560 | black pixel 1440.
# (1440, 998560, 0.14400000000000002)

# %% [markdown]
# # Main Loop

# %%
root = "./Before and after pictures/"
all_folders = os.listdir(root)
debug = False

output = []
for folder in all_folders:
    folder_path = os.path.join(root, folder)
    img_paths = os.listdir(folder_path)
    f_output = {}
    f_output["folder_path"] = folder
    for img_name in img_paths:
        col = img_name.split()[0].lower()
        img_path = os.path.join(folder_path, img_name)
        logger.info(img_path)
        img = io.imread(img_path, as_gray=True)
        bp, wp, bpp = get_pixel_count(img, debug=debug, fname=img_name)
        logger.info(f"{col} {bp} {wp}")
        f_output.update(
            {
                f"black pixel {col.upper()}" : bp,
                f"white pixel {col.upper()} " : wp,
                f"Percent black pixel {col.upper()}" : bpp,
                f"total pixel {col.upper()}" : bp+wp,
            }
        )
    
        # break
    output.append(f_output)
    # break
# Out:
# 2023-08-03 07:08:08.525 | INFO     | __main__:<module>:14 - ./Before and after pictures/M23/After M23.jpg
# 2023-08-03 07:08:08.596 | INFO     | __main__:get_pixel_count:5 - Best threshold 0.5111901110340389
# 2023-08-03 07:08:08.597 | INFO     | __main__:get_pixel_count:7 - Original Image (994, 1011) -> (1000, 1000)
# 2023-08-03 07:08:08.598 | INFO     | __main__:get_pixel_count:10 - After M23.jpg
# /tmp/ipykernel_7958/217959107.py:11: UserWarning: binary_output/bin_After M23.jpg is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
#   io.imsave(f"binary_output/bin_{fname}", binary_img)
# /tmp/ipykernel_7958/217959107.py:11: UserWarning: binary_output/bin_After M23.jpg is a low contrast image
#   io.imsave(f"binary_output/bin_{fname}", binary_img)
# 2023-08-03 07:08:08.617 | INFO     | __main__:<module>:17 - after 1440 998560
# 2023-08-03 07:08:08.617 | INFO     | __main__:<module>:14 - ./Before and after pictures/M23/Before M23.jpg
# 2023-08-03 07:08:08.689 | INFO     | __main__:get_pixel_count:5 - Best threshold 0.5498565934668658
# 2023-08-03 07:08:08.690 | INFO     | __main__:get_pixel_count:7 - Original Image (932, 982) -> (1000, 1000)
# 2023-08-03 07:08:08.690 | INFO     | __main__:get_pixel_count:10 - Before M23.jpg
# /tmp/ipykernel_7958/217959107.py:11: UserWarning: binary_output/bin_Before M23.jpg is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
#   io.imsave(f"binary_output/bin_{fname}", binary_img)
# /tmp/ipykernel_7958/217959107.py:11: UserWarning: binary_output/bin_Before M23.jpg is a low contrast image
#   io.imsave(f"binary_output/bin_{fname}", binary_img)
# 2023-08-03 07:08:08.712 | INFO     | __main__:<module>:17 - before 2989 997011
# 2023-08-03 07:08:08.713 | INFO     | __main__:<module>:14 - ./Before and after pictures/B36/After B36.jpg
# 2023-08-03 07:08:08.805 | INFO     | __main__:get_pixel_count:5 - Best threshold 0.5201246857050271
# 2023-08-03 07:08:08.806 | INFO     | __main__:get_pixel_count:7 - Original Image (805, 816) -> (1000, 1000)
# 2023-08-03 07:08:08.807 | INFO     | __main__:get_pixel_count:10 - After B36.jpg
# /tmp/ipykernel_7958/217959107.py:11: UserWarning: binary_output/bin_After B36.jpg is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
#   io.imsave(f"binary_output/bin_{fname}", binary_img)
# 2023-08-03 07:08:08.830 | INFO     | __main__:<module>:17 - after 45693 954307
# 2023-08-03 07:08:08.832 | INFO     | __main__:<module>:14 - ./Before and after pictures/B36/Before B36.jpg
# 2023-08-03 07:08:08.917 | INFO     | __main__:get_pixel_count:5 - Best threshold 0.5849590079053599
# 2023-08-03 07:08:08.919 | INFO     | __main__:get_pixel_count:7 - Original Image (1049, 1055) -> (1000, 1000)
# 2023-08-03 07:08:08.919 | INFO     | __main__:get_pixel_count:10 - Before B36.jpg
# /tmp/ipykernel_7958/217959107.py:11: UserWarning: binary_output/bin_Before B36.jpg is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
#   io.imsave(f"binary_output/bin_{fname}", binary_img)
# 2023-08-03 07:08:08.939 | INFO     | __main__:<module>:17 - before 11015 988985
# 2023-08-03 07:08:08.940 | INFO     | __main__:<module>:14 - ./Before and after pictures/M26/Before M26.jpg
# 2023-08-03 07:08:09.017 | INFO     | __main__:get_pixel_count:5 - Best threshold 0.4853657959969008
# 2023-08-03 07:08:09.018 | INFO     | __main__:get_pixel_count:7 - Original Image (984, 980) -> (1000, 1000)
# 2023-08-03 07:08:09.019 | INFO     | __main__:get_pixel_count:10 - Before M26.jpg
# /tmp/ipykernel_7958/217959107.py:11: UserWarning: binary_output/bin_Before M26.jpg is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
#   io.imsave(f"binary_output/bin_{fname}", binary_img)
# /tmp/ipykernel_7958/217959107.py:11: UserWarning: binary_output/bin_Before M26.jpg is a low contrast image
#   io.imsave(f"binary_output/bin_{fname}", binary_img)
# 2023-08-03 07:08:09.039 | INFO     | __main__:<module>:17 - before 695 999305
# 2023-08-03 07:08:09.039 | INFO     | __main__:<module>:14 - ./Before and after pictures/M26/After M26.jpg
# 2023-08-03 07:08:09.123 | INFO     | __main__:get_pixel_count:5 - Best threshold 0.5716946430943126
# 2023-08-03 07:08:09.125 | INFO     | __main__:get_pixel_count:7 - Original Image (901, 892) -> (1000, 1000)
# 2023-08-03 07:08:09.125 | INFO     | __main__:get_pixel_count:10 - After M26.jpg
# /tmp/ipykernel_7958/217959107.py:11: UserWarning: binary_output/bin_After M26.jpg is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
#   io.imsave(f"binary_output/bin_{fname}", binary_img)
# /tmp/ipykernel_7958/217959107.py:11: UserWarning: binary_output/bin_After M26.jpg is a low contrast image
#   io.imsave(f"binary_output/bin_{fname}", binary_img)
# 2023-08-03 07:08:09.146 | INFO     | __main__:<module>:17 - after 3991 996009
# 2023-08-03 07:08:09.147 | INFO     | __main__:<module>:14 - ./Before and after pictures/M28/Before M28.jpg
# 2023-08-03 07:08:09.230 | INFO     | __main__:get_pixel_count:5 - Best threshold 0.544592970189392
# 2023-08-03 07:08:09.231 | INFO     | __main__:get_pixel_count:7 - Original Image (1052, 1075) -> (1000, 1000)
# 2023-08-03 07:08:09.232 | INFO     | __main__:get_pixel_count:10 - Before M28.jpg
# /tmp/ipykernel_7958/217959107.py:11: UserWarning: binary_output/bin_Before M28.jpg is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
#   io.imsave(f"binary_output/bin_{fname}", binary_img)
# 2023-08-03 07:08:09.250 | INFO     | __main__:<module>:17 - before 20958 979042
# 2023-08-03 07:08:09.251 | INFO     | __main__:<module>:14 - ./Before and after pictures/M28/After M28.jpg
# 2023-08-03 07:08:09.348 | INFO     | __main__:get_pixel_count:5 - Best threshold 0.45924087819590054
# 2023-08-03 07:08:09.350 | INFO     | __main__:get_pixel_count:7 - Original Image (1289, 1353) -> (1000, 1000)
# 2023-08-03 07:08:09.350 | INFO     | __main__:get_pixel_count:10 - After M28.jpg
# /tmp/ipykernel_7958/217959107.py:11: UserWarning: binary_output/bin_After M28.jpg is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
#   io.imsave(f"binary_output/bin_{fname}", binary_img)
# /tmp/ipykernel_7958/217959107.py:11: UserWarning: binary_output/bin_After M28.jpg is a low contrast image
#   io.imsave(f"binary_output/bin_{fname}", binary_img)
# 2023-08-03 07:08:09.372 | INFO     | __main__:<module>:17 - after 1562 998438
# 2023-08-03 07:08:09.373 | INFO     | __main__:<module>:14 - ./Before and after pictures/B37/Before B37.jpg
# 2023-08-03 07:08:09.464 | INFO     | __main__:get_pixel_count:5 - Best threshold 0.541062395483222
# 2023-08-03 07:08:09.465 | INFO     | __main__:get_pixel_count:7 - Original Image (1006, 992) -> (1000, 1000)
# 2023-08-03 07:08:09.466 | INFO     | __main__:get_pixel_count:10 - Before B37.jpg
# /tmp/ipykernel_7958/217959107.py:11: UserWarning: binary_output/bin_Before B37.jpg is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
#   io.imsave(f"binary_output/bin_{fname}", binary_img)
# /tmp/ipykernel_7958/217959107.py:11: UserWarning: binary_output/bin_Before B37.jpg is a low contrast image
#   io.imsave(f"binary_output/bin_{fname}", binary_img)
# 2023-08-03 07:08:09.484 | INFO     | __main__:<module>:17 - before 2971 997029
# 2023-08-03 07:08:09.485 | INFO     | __main__:<module>:14 - ./Before and after pictures/B37/After B37.jpg
# 2023-08-03 07:08:09.563 | INFO     | __main__:get_pixel_count:5 - Best threshold 0.6604629234256437
# 2023-08-03 07:08:09.565 | INFO     | __main__:get_pixel_count:7 - Original Image (867, 869) -> (1000, 1000)
# 2023-08-03 07:08:09.565 | INFO     | __main__:get_pixel_count:10 - After B37.jpg
# /tmp/ipykernel_7958/217959107.py:11: UserWarning: binary_output/bin_After B37.jpg is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
#   io.imsave(f"binary_output/bin_{fname}", binary_img)
# /tmp/ipykernel_7958/217959107.py:11: UserWarning: binary_output/bin_After B37.jpg is a low contrast image
#   io.imsave(f"binary_output/bin_{fname}", binary_img)
# 2023-08-03 07:08:09.583 | INFO     | __main__:<module>:17 - after 9593 990407
# 2023-08-03 07:08:09.584 | INFO     | __main__:<module>:14 - ./Before and after pictures/M19/Before M19.jpg
# 2023-08-03 07:08:09.667 | INFO     | __main__:get_pixel_count:5 - Best threshold 0.3083407080839734
# 2023-08-03 07:08:09.668 | INFO     | __main__:get_pixel_count:7 - Original Image (1072, 1110) -> (1000, 1000)
# 2023-08-03 07:08:09.669 | INFO     | __main__:get_pixel_count:10 - Before M19.jpg
# /tmp/ipykernel_7958/217959107.py:11: UserWarning: binary_output/bin_Before M19.jpg is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
#   io.imsave(f"binary_output/bin_{fname}", binary_img)
# /tmp/ipykernel_7958/217959107.py:11: UserWarning: binary_output/bin_Before M19.jpg is a low contrast image
#   io.imsave(f"binary_output/bin_{fname}", binary_img)
# 2023-08-03 07:08:09.683 | INFO     | __main__:<module>:17 - before 895 999105
# 2023-08-03 07:08:09.684 | INFO     | __main__:<module>:14 - ./Before and after pictures/M19/After M19.jpg
# 2023-08-03 07:08:09.748 | INFO     | __main__:get_pixel_count:5 - Best threshold 0.705485218402934
# 2023-08-03 07:08:09.750 | INFO     | __main__:get_pixel_count:7 - Original Image (785, 796) -> (1000, 1000)
# 2023-08-03 07:08:09.750 | INFO     | __main__:get_pixel_count:10 - After M19.jpg
# /tmp/ipykernel_7958/217959107.py:11: UserWarning: binary_output/bin_After M19.jpg is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
#   io.imsave(f"binary_output/bin_{fname}", binary_img)
# 2023-08-03 07:08:09.769 | INFO     | __main__:<module>:17 - after 694457 305543
# 2023-08-03 07:08:09.769 | INFO     | __main__:<module>:14 - ./Before and after pictures/B33/After B33.jpg
# 2023-08-03 07:08:09.850 | INFO     | __main__:get_pixel_count:5 - Best threshold 0.6910421599812245
# 2023-08-03 07:08:09.852 | INFO     | __main__:get_pixel_count:7 - Original Image (1113, 1141) -> (1000, 1000)
# 2023-08-03 07:08:09.853 | INFO     | __main__:get_pixel_count:10 - After B33.jpg
# /tmp/ipykernel_7958/217959107.py:11: UserWarning: binary_output/bin_After B33.jpg is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
#   io.imsave(f"binary_output/bin_{fname}", binary_img)
# 2023-08-03 07:08:09.873 | INFO     | __main__:<module>:17 - after 25682 974318
# 2023-08-03 07:08:09.874 | INFO     | __main__:<module>:14 - ./Before and after pictures/B33/Before B33.jpg
# 2023-08-03 07:08:09.950 | INFO     | __main__:get_pixel_count:5 - Best threshold 0.7276762147485912
# 2023-08-03 07:08:09.951 | INFO     | __main__:get_pixel_count:7 - Original Image (901, 896) -> (1000, 1000)
# 2023-08-03 07:08:09.952 | INFO     | __main__:get_pixel_count:10 - Before B33.jpg
# /tmp/ipykernel_7958/217959107.py:11: UserWarning: binary_output/bin_Before B33.jpg is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
#   io.imsave(f"binary_output/bin_{fname}", binary_img)
# /tmp/ipykernel_7958/217959107.py:11: UserWarning: binary_output/bin_Before B33.jpg is a low contrast image
#   io.imsave(f"binary_output/bin_{fname}", binary_img)
# 2023-08-03 07:08:09.971 | INFO     | __main__:<module>:17 - before 5528 994472
# 2023-08-03 07:08:09.972 | INFO     | __main__:<module>:14 - ./Before and after pictures/B22/Before B22.jpg
# 2023-08-03 07:08:10.051 | INFO     | __main__:get_pixel_count:5 - Best threshold 0.5069998311777675
# 2023-08-03 07:08:10.053 | INFO     | __main__:get_pixel_count:7 - Original Image (1042, 1032) -> (1000, 1000)
# 2023-08-03 07:08:10.053 | INFO     | __main__:get_pixel_count:10 - Before B22.jpg
# /tmp/ipykernel_7958/217959107.py:11: UserWarning: binary_output/bin_Before B22.jpg is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
#   io.imsave(f"binary_output/bin_{fname}", binary_img)
# /tmp/ipykernel_7958/217959107.py:11: UserWarning: binary_output/bin_Before B22.jpg is a low contrast image
#   io.imsave(f"binary_output/bin_{fname}", binary_img)
# 2023-08-03 07:08:10.071 | INFO     | __main__:<module>:17 - before 4399 995601
# 2023-08-03 07:08:10.072 | INFO     | __main__:<module>:14 - ./Before and after pictures/B22/After B22.jpg
# 2023-08-03 07:08:10.149 | INFO     | __main__:get_pixel_count:5 - Best threshold 0.35780030416013
# 2023-08-03 07:08:10.150 | INFO     | __main__:get_pixel_count:7 - Original Image (1111, 1078) -> (1000, 1000)
# 2023-08-03 07:08:10.151 | INFO     | __main__:get_pixel_count:10 - After B22.jpg
# /tmp/ipykernel_7958/217959107.py:11: UserWarning: binary_output/bin_After B22.jpg is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
#   io.imsave(f"binary_output/bin_{fname}", binary_img)
# /tmp/ipykernel_7958/217959107.py:11: UserWarning: binary_output/bin_After B22.jpg is a low contrast image
#   io.imsave(f"binary_output/bin_{fname}", binary_img)
# 2023-08-03 07:08:10.172 | INFO     | __main__:<module>:17 - after 9345 990655
# 2023-08-03 07:08:10.172 | INFO     | __main__:<module>:14 - ./Before and after pictures/M33/After M33.jpg
# 2023-08-03 07:08:10.250 | INFO     | __main__:get_pixel_count:5 - Best threshold 0.5261831177413947
# 2023-08-03 07:08:10.251 | INFO     | __main__:get_pixel_count:7 - Original Image (1020, 1075) -> (1000, 1000)
# 2023-08-03 07:08:10.252 | INFO     | __main__:get_pixel_count:10 - After M33.jpg
# /tmp/ipykernel_7958/217959107.py:11: UserWarning: binary_output/bin_After M33.jpg is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
#   io.imsave(f"binary_output/bin_{fname}", binary_img)
# /tmp/ipykernel_7958/217959107.py:11: UserWarning: binary_output/bin_After M33.jpg is a low contrast image
#   io.imsave(f"binary_output/bin_{fname}", binary_img)
# 2023-08-03 07:08:10.273 | INFO     | __main__:<module>:17 - after 6891 993109
# 2023-08-03 07:08:10.274 | INFO     | __main__:<module>:14 - ./Before and after pictures/M33/Before M33.jpg
# 2023-08-03 07:08:10.341 | INFO     | __main__:get_pixel_count:5 - Best threshold 0.4431796148036777
# 2023-08-03 07:08:10.342 | INFO     | __main__:get_pixel_count:7 - Original Image (986, 994) -> (1000, 1000)
# 2023-08-03 07:08:10.343 | INFO     | __main__:get_pixel_count:10 - Before M33.jpg
# /tmp/ipykernel_7958/217959107.py:11: UserWarning: binary_output/bin_Before M33.jpg is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
#   io.imsave(f"binary_output/bin_{fname}", binary_img)
# /tmp/ipykernel_7958/217959107.py:11: UserWarning: binary_output/bin_Before M33.jpg is a low contrast image
#   io.imsave(f"binary_output/bin_{fname}", binary_img)
# 2023-08-03 07:08:10.361 | INFO     | __main__:<module>:17 - before 7698 992302
# 2023-08-03 07:08:10.361 | INFO     | __main__:<module>:14 - ./Before and after pictures/M36/Before M36.jpg
# 2023-08-03 07:08:10.452 | INFO     | __main__:get_pixel_count:5 - Best threshold 0.6760979213912917
# 2023-08-03 07:08:10.453 | INFO     | __main__:get_pixel_count:7 - Original Image (936, 941) -> (1000, 1000)
# 2023-08-03 07:08:10.454 | INFO     | __main__:get_pixel_count:10 - Before M36.jpg
# /tmp/ipykernel_7958/217959107.py:11: UserWarning: binary_output/bin_Before M36.jpg is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
#   io.imsave(f"binary_output/bin_{fname}", binary_img)
# /tmp/ipykernel_7958/217959107.py:11: UserWarning: binary_output/bin_Before M36.jpg is a low contrast image
#   io.imsave(f"binary_output/bin_{fname}", binary_img)
# 2023-08-03 07:08:10.473 | INFO     | __main__:<module>:17 - before 1134 998866
# 2023-08-03 07:08:10.474 | INFO     | __main__:<module>:14 - ./Before and after pictures/M36/After M36.jpg
# 2023-08-03 07:08:10.555 | INFO     | __main__:get_pixel_count:5 - Best threshold 0.5637154464224843
# 2023-08-03 07:08:10.556 | INFO     | __main__:get_pixel_count:7 - Original Image (937, 946) -> (1000, 1000)
# 2023-08-03 07:08:10.557 | INFO     | __main__:get_pixel_count:10 - After M36.jpg
# /tmp/ipykernel_7958/217959107.py:11: UserWarning: binary_output/bin_After M36.jpg is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
#   io.imsave(f"binary_output/bin_{fname}", binary_img)
# /tmp/ipykernel_7958/217959107.py:11: UserWarning: binary_output/bin_After M36.jpg is a low contrast image
#   io.imsave(f"binary_output/bin_{fname}", binary_img)
# 2023-08-03 07:08:10.572 | INFO     | __main__:<module>:17 - after 2996 997004
# 2023-08-03 07:08:10.574 | INFO     | __main__:<module>:14 - ./Before and after pictures/M25/Before M25.jpg
# 2023-08-03 07:08:10.640 | INFO     | __main__:get_pixel_count:5 - Best threshold 0.5168490976438356
# 2023-08-03 07:08:10.641 | INFO     | __main__:get_pixel_count:7 - Original Image (968, 962) -> (1000, 1000)
# 2023-08-03 07:08:10.642 | INFO     | __main__:get_pixel_count:10 - Before M25.jpg
# /tmp/ipykernel_7958/217959107.py:11: UserWarning: binary_output/bin_Before M25.jpg is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
#   io.imsave(f"binary_output/bin_{fname}", binary_img)
# /tmp/ipykernel_7958/217959107.py:11: UserWarning: binary_output/bin_Before M25.jpg is a low contrast image
#   io.imsave(f"binary_output/bin_{fname}", binary_img)
# 2023-08-03 07:08:10.662 | INFO     | __main__:<module>:17 - before 4155 995845
# 2023-08-03 07:08:10.663 | INFO     | __main__:<module>:14 - ./Before and after pictures/M25/After M25.jpg
# 2023-08-03 07:08:10.738 | INFO     | __main__:get_pixel_count:5 - Best threshold 0.4816257675534657
# 2023-08-03 07:08:10.740 | INFO     | __main__:get_pixel_count:7 - Original Image (1037, 1068) -> (1000, 1000)
# 2023-08-03 07:08:10.740 | INFO     | __main__:get_pixel_count:10 - After M25.jpg
# /tmp/ipykernel_7958/217959107.py:11: UserWarning: binary_output/bin_After M25.jpg is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
#   io.imsave(f"binary_output/bin_{fname}", binary_img)
# 2023-08-03 07:08:10.758 | INFO     | __main__:<module>:17 - after 13763 986237
# 2023-08-03 07:08:10.759 | INFO     | __main__:<module>:14 - ./Before and after pictures/B28/Before B28.jpg
# 2023-08-03 07:08:10.832 | INFO     | __main__:get_pixel_count:5 - Best threshold 0.653042573622677
# 2023-08-03 07:08:10.833 | INFO     | __main__:get_pixel_count:7 - Original Image (1012, 1050) -> (1000, 1000)
# 2023-08-03 07:08:10.834 | INFO     | __main__:get_pixel_count:10 - Before B28.jpg
# /tmp/ipykernel_7958/217959107.py:11: UserWarning: binary_output/bin_Before B28.jpg is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
#   io.imsave(f"binary_output/bin_{fname}", binary_img)
# /tmp/ipykernel_7958/217959107.py:11: UserWarning: binary_output/bin_Before B28.jpg is a low contrast image
#   io.imsave(f"binary_output/bin_{fname}", binary_img)
# 2023-08-03 07:08:10.856 | INFO     | __main__:<module>:17 - before 8188 991812
# 2023-08-03 07:08:10.857 | INFO     | __main__:<module>:14 - ./Before and after pictures/B28/After B28.jpg
# 2023-08-03 07:08:10.951 | INFO     | __main__:get_pixel_count:5 - Best threshold 0.5496985606323064
# 2023-08-03 07:08:10.953 | INFO     | __main__:get_pixel_count:7 - Original Image (1064, 1090) -> (1000, 1000)
# 2023-08-03 07:08:10.953 | INFO     | __main__:get_pixel_count:10 - After B28.jpg
# /tmp/ipykernel_7958/217959107.py:11: UserWarning: binary_output/bin_After B28.jpg is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
#   io.imsave(f"binary_output/bin_{fname}", binary_img)
# 2023-08-03 07:08:10.976 | INFO     | __main__:<module>:17 - after 19488 980512
# 2023-08-03 07:08:10.978 | INFO     | __main__:<module>:14 - ./Before and after pictures/M29/Before M29.jpg
# 2023-08-03 07:08:11.045 | INFO     | __main__:get_pixel_count:5 - Best threshold 0.4632364550973098
# 2023-08-03 07:08:11.046 | INFO     | __main__:get_pixel_count:7 - Original Image (862, 872) -> (1000, 1000)
# 2023-08-03 07:08:11.047 | INFO     | __main__:get_pixel_count:10 - Before M29.jpg
# /tmp/ipykernel_7958/217959107.py:11: UserWarning: binary_output/bin_Before M29.jpg is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
#   io.imsave(f"binary_output/bin_{fname}", binary_img)
# /tmp/ipykernel_7958/217959107.py:11: UserWarning: binary_output/bin_Before M29.jpg is a low contrast image
#   io.imsave(f"binary_output/bin_{fname}", binary_img)
# 2023-08-03 07:08:11.068 | INFO     | __main__:<module>:17 - before 511 999489
# 2023-08-03 07:08:11.069 | INFO     | __main__:<module>:14 - ./Before and after pictures/M29/After M29.jpg
# 2023-08-03 07:08:11.146 | INFO     | __main__:get_pixel_count:5 - Best threshold 0.48671906179362895
# 2023-08-03 07:08:11.148 | INFO     | __main__:get_pixel_count:7 - Original Image (991, 1016) -> (1000, 1000)
# 2023-08-03 07:08:11.148 | INFO     | __main__:get_pixel_count:10 - After M29.jpg
# /tmp/ipykernel_7958/217959107.py:11: UserWarning: binary_output/bin_After M29.jpg is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
#   io.imsave(f"binary_output/bin_{fname}", binary_img)
# /tmp/ipykernel_7958/217959107.py:11: UserWarning: binary_output/bin_After M29.jpg is a low contrast image
#   io.imsave(f"binary_output/bin_{fname}", binary_img)
# 2023-08-03 07:08:11.167 | INFO     | __main__:<module>:17 - after 377 999623
# 2023-08-03 07:08:11.168 | INFO     | __main__:<module>:14 - ./Before and after pictures/B29/Before B29.jpg
# 2023-08-03 07:08:11.250 | INFO     | __main__:get_pixel_count:5 - Best threshold 0.4701439011396513
# 2023-08-03 07:08:11.251 | INFO     | __main__:get_pixel_count:7 - Original Image (1086, 1099) -> (1000, 1000)
# 2023-08-03 07:08:11.252 | INFO     | __main__:get_pixel_count:10 - Before B29.jpg
# /tmp/ipykernel_7958/217959107.py:11: UserWarning: binary_output/bin_Before B29.jpg is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
#   io.imsave(f"binary_output/bin_{fname}", binary_img)
# 2023-08-03 07:08:11.271 | INFO     | __main__:<module>:17 - before 20510 979490
# 2023-08-03 07:08:11.272 | INFO     | __main__:<module>:14 - ./Before and after pictures/B29/After B29.jpg
# 2023-08-03 07:08:11.338 | INFO     | __main__:get_pixel_count:5 - Best threshold 0.6533841526045978
# 2023-08-03 07:08:11.339 | INFO     | __main__:get_pixel_count:7 - Original Image (860, 876) -> (1000, 1000)
# 2023-08-03 07:08:11.339 | INFO     | __main__:get_pixel_count:10 - After B29.jpg
# /tmp/ipykernel_7958/217959107.py:11: UserWarning: binary_output/bin_After B29.jpg is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
#   io.imsave(f"binary_output/bin_{fname}", binary_img)
# 2023-08-03 07:08:11.358 | INFO     | __main__:<module>:17 - after 32529 967471
# 2023-08-03 07:08:11.358 | INFO     | __main__:<module>:14 - ./Before and after pictures/B26/After B26.jpg
# 2023-08-03 07:08:11.429 | INFO     | __main__:get_pixel_count:5 - Best threshold 0.6243524433521871
# 2023-08-03 07:08:11.431 | INFO     | __main__:get_pixel_count:7 - Original Image (963, 982) -> (1000, 1000)
# 2023-08-03 07:08:11.432 | INFO     | __main__:get_pixel_count:10 - After B26.jpg
# /tmp/ipykernel_7958/217959107.py:11: UserWarning: binary_output/bin_After B26.jpg is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
#   io.imsave(f"binary_output/bin_{fname}", binary_img)
# 2023-08-03 07:08:11.454 | INFO     | __main__:<module>:17 - after 18462 981538
# 2023-08-03 07:08:11.455 | INFO     | __main__:<module>:14 - ./Before and after pictures/B26/Before B26.jpg
# 2023-08-03 07:08:11.527 | INFO     | __main__:get_pixel_count:5 - Best threshold 0.4099912637944477
# 2023-08-03 07:08:11.529 | INFO     | __main__:get_pixel_count:7 - Original Image (1001, 1048) -> (1000, 1000)
# 2023-08-03 07:08:11.529 | INFO     | __main__:get_pixel_count:10 - Before B26.jpg
# /tmp/ipykernel_7958/217959107.py:11: UserWarning: binary_output/bin_Before B26.jpg is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
#   io.imsave(f"binary_output/bin_{fname}", binary_img)
# /tmp/ipykernel_7958/217959107.py:11: UserWarning: binary_output/bin_Before B26.jpg is a low contrast image
#   io.imsave(f"binary_output/bin_{fname}", binary_img)
# 2023-08-03 07:08:11.543 | INFO     | __main__:<module>:17 - before 1201 998799
# 2023-08-03 07:08:11.544 | INFO     | __main__:<module>:14 - ./Before and after pictures/M22/Before M22.jpg
# 2023-08-03 07:08:11.617 | INFO     | __main__:get_pixel_count:5 - Best threshold 0.5168490976438356
# 2023-08-03 07:08:11.618 | INFO     | __main__:get_pixel_count:7 - Original Image (968, 962) -> (1000, 1000)
# 2023-08-03 07:08:11.619 | INFO     | __main__:get_pixel_count:10 - Before M22.jpg
# /tmp/ipykernel_7958/217959107.py:11: UserWarning: binary_output/bin_Before M22.jpg is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
#   io.imsave(f"binary_output/bin_{fname}", binary_img)
# /tmp/ipykernel_7958/217959107.py:11: UserWarning: binary_output/bin_Before M22.jpg is a low contrast image
#   io.imsave(f"binary_output/bin_{fname}", binary_img)
# 2023-08-03 07:08:11.637 | INFO     | __main__:<module>:17 - before 4155 995845
# 2023-08-03 07:08:11.638 | INFO     | __main__:<module>:14 - ./Before and after pictures/M22/After M22.jpg
# 2023-08-03 07:08:11.718 | INFO     | __main__:get_pixel_count:5 - Best threshold 0.43559587717122933
# 2023-08-03 07:08:11.720 | INFO     | __main__:get_pixel_count:7 - Original Image (1062, 1032) -> (1000, 1000)
# 2023-08-03 07:08:11.720 | INFO     | __main__:get_pixel_count:10 - After M22.jpg
# /tmp/ipykernel_7958/217959107.py:11: UserWarning: binary_output/bin_After M22.jpg is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
#   io.imsave(f"binary_output/bin_{fname}", binary_img)
# /tmp/ipykernel_7958/217959107.py:11: UserWarning: binary_output/bin_After M22.jpg is a low contrast image
#   io.imsave(f"binary_output/bin_{fname}", binary_img)
# 2023-08-03 07:08:11.739 | INFO     | __main__:<module>:17 - after 1554 998446
# 2023-08-03 07:08:11.740 | INFO     | __main__:<module>:14 - ./Before and after pictures/M34/Before M34.jpg
# 2023-08-03 07:08:11.817 | INFO     | __main__:get_pixel_count:5 - Best threshold 0.5540465321139525
# 2023-08-03 07:08:11.818 | INFO     | __main__:get_pixel_count:7 - Original Image (1011, 1005) -> (1000, 1000)
# 2023-08-03 07:08:11.819 | INFO     | __main__:get_pixel_count:10 - Before M34.jpg
# /tmp/ipykernel_7958/217959107.py:11: UserWarning: binary_output/bin_Before M34.jpg is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
#   io.imsave(f"binary_output/bin_{fname}", binary_img)
# /tmp/ipykernel_7958/217959107.py:11: UserWarning: binary_output/bin_Before M34.jpg is a low contrast image
#   io.imsave(f"binary_output/bin_{fname}", binary_img)
# 2023-08-03 07:08:11.835 | INFO     | __main__:<module>:17 - before 4426 995574
# 2023-08-03 07:08:11.836 | INFO     | __main__:<module>:14 - ./Before and after pictures/M34/After M34.jpg
# 2023-08-03 07:08:11.916 | INFO     | __main__:get_pixel_count:5 - Best threshold 0.47685549562152896
# 2023-08-03 07:08:11.917 | INFO     | __main__:get_pixel_count:7 - Original Image (920, 912) -> (1000, 1000)
# 2023-08-03 07:08:11.918 | INFO     | __main__:get_pixel_count:10 - After M34.jpg
# /tmp/ipykernel_7958/217959107.py:11: UserWarning: binary_output/bin_After M34.jpg is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
#   io.imsave(f"binary_output/bin_{fname}", binary_img)
# /tmp/ipykernel_7958/217959107.py:11: UserWarning: binary_output/bin_After M34.jpg is a low contrast image
#   io.imsave(f"binary_output/bin_{fname}", binary_img)
# 2023-08-03 07:08:11.934 | INFO     | __main__:<module>:17 - after 8096 991904
# 2023-08-03 07:08:11.935 | INFO     | __main__:<module>:14 - ./Before and after pictures/B23/Before B23.jpg
# 2023-08-03 07:08:12.014 | INFO     | __main__:get_pixel_count:5 - Best threshold 0.5578004535362704
# 2023-08-03 07:08:12.016 | INFO     | __main__:get_pixel_count:7 - Original Image (1137, 1151) -> (1000, 1000)
# 2023-08-03 07:08:12.017 | INFO     | __main__:get_pixel_count:10 - Before B23.jpg
# /tmp/ipykernel_7958/217959107.py:11: UserWarning: binary_output/bin_Before B23.jpg is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
#   io.imsave(f"binary_output/bin_{fname}", binary_img)
# 2023-08-03 07:08:12.039 | INFO     | __main__:<module>:17 - before 14070 985930
# 2023-08-03 07:08:12.039 | INFO     | __main__:<module>:14 - ./Before and after pictures/B23/After B23.jpg
# 2023-08-03 07:08:12.119 | INFO     | __main__:get_pixel_count:5 - Best threshold 0.5650982551828255
# 2023-08-03 07:08:12.120 | INFO     | __main__:get_pixel_count:7 - Original Image (1052, 1063) -> (1000, 1000)
# 2023-08-03 07:08:12.121 | INFO     | __main__:get_pixel_count:10 - After B23.jpg
# /tmp/ipykernel_7958/217959107.py:11: UserWarning: binary_output/bin_After B23.jpg is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
#   io.imsave(f"binary_output/bin_{fname}", binary_img)
# 2023-08-03 07:08:12.141 | INFO     | __main__:<module>:17 - after 52795 947205
# 2023-08-03 07:08:12.141 | INFO     | __main__:<module>:14 - ./Before and after pictures/M37/Before M37.jpg
# 2023-08-03 07:08:12.225 | INFO     | __main__:get_pixel_count:5 - Best threshold 0.5868220612610963
# 2023-08-03 07:08:12.226 | INFO     | __main__:get_pixel_count:7 - Original Image (850, 866) -> (1000, 1000)
# 2023-08-03 07:08:12.227 | INFO     | __main__:get_pixel_count:10 - Before M37.jpg
# /tmp/ipykernel_7958/217959107.py:11: UserWarning: binary_output/bin_Before M37.jpg is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
#   io.imsave(f"binary_output/bin_{fname}", binary_img)
# /tmp/ipykernel_7958/217959107.py:11: UserWarning: binary_output/bin_Before M37.jpg is a low contrast image
#   io.imsave(f"binary_output/bin_{fname}", binary_img)
# 2023-08-03 07:08:12.242 | INFO     | __main__:<module>:17 - before 6168 993832
# 2023-08-03 07:08:12.243 | INFO     | __main__:<module>:14 - ./Before and after pictures/M37/After M37.jpg
# 2023-08-03 07:08:12.310 | INFO     | __main__:get_pixel_count:5 - Best threshold 0.5095117342844993
# 2023-08-03 07:08:12.311 | INFO     | __main__:get_pixel_count:7 - Original Image (895, 925) -> (1000, 1000)
# 2023-08-03 07:08:12.312 | INFO     | __main__:get_pixel_count:10 - After M37.jpg
# /tmp/ipykernel_7958/217959107.py:11: UserWarning: binary_output/bin_After M37.jpg is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
#   io.imsave(f"binary_output/bin_{fname}", binary_img)
# /tmp/ipykernel_7958/217959107.py:11: UserWarning: binary_output/bin_After M37.jpg is a low contrast image
#   io.imsave(f"binary_output/bin_{fname}", binary_img)
# 2023-08-03 07:08:12.328 | INFO     | __main__:<module>:17 - after 8369 991631
# 2023-08-03 07:08:12.329 | INFO     | __main__:<module>:14 - ./Before and after pictures/B19/After B19.jpg
# 2023-08-03 07:08:12.407 | INFO     | __main__:get_pixel_count:5 - Best threshold 0.4428187379650171
# 2023-08-03 07:08:12.408 | INFO     | __main__:get_pixel_count:7 - Original Image (1062, 1092) -> (1000, 1000)
# 2023-08-03 07:08:12.409 | INFO     | __main__:get_pixel_count:10 - After B19.jpg
# /tmp/ipykernel_7958/217959107.py:11: UserWarning: binary_output/bin_After B19.jpg is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
#   io.imsave(f"binary_output/bin_{fname}", binary_img)
# /tmp/ipykernel_7958/217959107.py:11: UserWarning: binary_output/bin_After B19.jpg is a low contrast image
#   io.imsave(f"binary_output/bin_{fname}", binary_img)
# 2023-08-03 07:08:12.426 | INFO     | __main__:<module>:17 - after 5572 994428
# 2023-08-03 07:08:12.426 | INFO     | __main__:<module>:14 - ./Before and after pictures/B19/Before B19.jpg
# 2023-08-03 07:08:12.520 | INFO     | __main__:get_pixel_count:5 - Best threshold 0.5016453572650186
# 2023-08-03 07:08:12.522 | INFO     | __main__:get_pixel_count:7 - Original Image (1328, 1330) -> (1000, 1000)
# 2023-08-03 07:08:12.522 | INFO     | __main__:get_pixel_count:10 - Before B19.jpg
# /tmp/ipykernel_7958/217959107.py:11: UserWarning: binary_output/bin_Before B19.jpg is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
#   io.imsave(f"binary_output/bin_{fname}", binary_img)
# /tmp/ipykernel_7958/217959107.py:11: UserWarning: binary_output/bin_Before B19.jpg is a low contrast image
#   io.imsave(f"binary_output/bin_{fname}", binary_img)
# 2023-08-03 07:08:12.545 | INFO     | __main__:<module>:17 - before 5180 994820
# 2023-08-03 07:08:12.546 | INFO     | __main__:<module>:14 - ./Before and after pictures/B25/Before B25.jpg
# 2023-08-03 07:08:12.626 | INFO     | __main__:get_pixel_count:5 - Best threshold 0.6105033723937002
# 2023-08-03 07:08:12.628 | INFO     | __main__:get_pixel_count:7 - Original Image (960, 963) -> (1000, 1000)
# 2023-08-03 07:08:12.628 | INFO     | __main__:get_pixel_count:10 - Before B25.jpg
# /tmp/ipykernel_7958/217959107.py:11: UserWarning: binary_output/bin_Before B25.jpg is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
#   io.imsave(f"binary_output/bin_{fname}", binary_img)
# 2023-08-03 07:08:12.648 | INFO     | __main__:<module>:17 - before 72554 927446
# 2023-08-03 07:08:12.649 | INFO     | __main__:<module>:14 - ./Before and after pictures/B25/After B25.jpg
# 2023-08-03 07:08:12.771 | INFO     | __main__:get_pixel_count:5 - Best threshold 0.6065153206646257
# 2023-08-03 07:08:12.772 | INFO     | __main__:get_pixel_count:7 - Original Image (1250, 1262) -> (1000, 1000)
# 2023-08-03 07:08:12.773 | INFO     | __main__:get_pixel_count:10 - After B25.jpg
# /tmp/ipykernel_7958/217959107.py:11: UserWarning: binary_output/bin_After B25.jpg is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
#   io.imsave(f"binary_output/bin_{fname}", binary_img)
# 2023-08-03 07:08:12.790 | INFO     | __main__:<module>:17 - after 110786 889214
# 2023-08-03 07:08:12.791 | INFO     | __main__:<module>:14 - ./Before and after pictures/B34/After B34.jpg
# 2023-08-03 07:08:12.874 | INFO     | __main__:get_pixel_count:5 - Best threshold 0.4904191114577779
# 2023-08-03 07:08:12.875 | INFO     | __main__:get_pixel_count:7 - Original Image (970, 962) -> (1000, 1000)
# 2023-08-03 07:08:12.876 | INFO     | __main__:get_pixel_count:10 - After B34.jpg
# /tmp/ipykernel_7958/217959107.py:11: UserWarning: binary_output/bin_After B34.jpg is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
#   io.imsave(f"binary_output/bin_{fname}", binary_img)
# /tmp/ipykernel_7958/217959107.py:11: UserWarning: binary_output/bin_After B34.jpg is a low contrast image
#   io.imsave(f"binary_output/bin_{fname}", binary_img)
# 2023-08-03 07:08:12.897 | INFO     | __main__:<module>:17 - after 7472 992528
# 2023-08-03 07:08:12.898 | INFO     | __main__:<module>:14 - ./Before and after pictures/B34/Before B34.jpg
# 2023-08-03 07:08:13.001 | INFO     | __main__:get_pixel_count:5 - Best threshold 0.41561539709059997
# 2023-08-03 07:08:13.003 | INFO     | __main__:get_pixel_count:7 - Original Image (1036, 1038) -> (1000, 1000)
# 2023-08-03 07:08:13.003 | INFO     | __main__:get_pixel_count:10 - Before B34.jpg
# /tmp/ipykernel_7958/217959107.py:11: UserWarning: binary_output/bin_Before B34.jpg is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
#   io.imsave(f"binary_output/bin_{fname}", binary_img)
# /tmp/ipykernel_7958/217959107.py:11: UserWarning: binary_output/bin_Before B34.jpg is a low contrast image
#   io.imsave(f"binary_output/bin_{fname}", binary_img)
# 2023-08-03 07:08:13.019 | INFO     | __main__:<module>:17 - before 3319 996681

# %%
df = pd.DataFrame(output)
df.head()
# Out:
#   folder_path  black pixel AFTER  white pixel AFTER   \
# 0         M23               1440              998560
# 1         B36              45693              954307
# 2         M26               3991              996009
# 3         M28               1562              998438
# 4         B37               9593              990407
#
#    Percent black pixel AFTER  total pixel AFTER  black pixel BEFORE  \
# 0                     0.1440            1000000                2989
# 1                     4.5693            1000000               11015
# 2                     0.3991            1000000                 695
# 3                     0.1562            1000000               20958
# 4                     0.9593            1000000                2971
#
#    white pixel BEFORE   Percent black pixel BEFORE  total pixel BEFORE
# 0               997011                      0.2989             1000000
# 1               988985                      1.1015             1000000
# 2               999305                      0.0695             1000000
# 3               979042                      2.0958             1000000
# 4               997029                      0.2971             1000000

# %%
# output

# %%
x = "black pixel AFTER"
y = "black pixel BEFORE"

df["relative_change [(after-before)/before]"] = ((df[x] - df[y]) / df[y])*100
df.head()
# Out:
#   folder_path  black pixel AFTER  white pixel AFTER   \
# 0         M23               1440              998560
# 1         B36              45693              954307
# 2         M26               3991              996009
# 3         M28               1562              998438
# 4         B37               9593              990407
#
#    Percent black pixel AFTER  total pixel AFTER  black pixel BEFORE  \
# 0                     0.1440            1000000                2989
# 1                     4.5693            1000000               11015
# 2                     0.3991            1000000                 695
# 3                     0.1562            1000000               20958
# 4                     0.9593            1000000                2971
#
#    white pixel BEFORE   Percent black pixel BEFORE  total pixel BEFORE  \
# 0               997011                      0.2989             1000000
# 1               988985                      1.1015             1000000
# 2               999305                      0.0695             1000000
# 3               979042                      2.0958             1000000
# 4               997029                      0.2971             1000000
#
#    relative_change [(after-before)/before]
# 0                               -51.823352
# 1                               314.825238
# 2                               474.244604
# 3                               -92.546999
# 4                               222.887917

# %%
df.to_csv("aug_3_result.csv", index=False)
